# %% [markdown]
# ## Perform Basic Pandas Data Operations

# %% [markdown]
# ### 1. <b> Reading CSV file <b>

# %%
# import pandas library for data manipulation
import pandas as pd
# import numpy as np to perform operations on array.
import numpy as np

# here pandas read_csv function is used to read the .csv file
# which resides on your system.
filepath="/Users/sarael-metwally/Documents/Weather_Data.csv"
df = pd.read_csv(filepath)
df
# Out:
#          Date and Time  Battery Voltage  CR10 Temperature  \
# 0     01/01/2004 00:00            14.13             13.77
# 1     01/01/2004 01:00            14.14             13.75
# 2     01/01/2004 02:00            14.14             13.71
# 3     01/01/2004 03:00            14.14             13.62
# 4     01/01/2004 04:00            14.14             13.55
# ...                ...              ...               ...
# 8779  31/12/2004 19:00            14.06             16.14
# 8780  31/12/2004 20:00            14.06             16.16
# 8781  31/12/2004 21:00            14.05             16.18
# 8782  31/12/2004 22:00            14.05             16.18
# 8783  31/12/2004 23:00            14.06             16.14
#
#       Wind Direction 10 Minutes  Wind Speed 10 Minutes  Wind Gust 10 Minutes  \
# 0                         175.5                  7.590                13.290
# 1                         191.5                 13.270                25.480
# ...

# %% [markdown]
# ### 2. <b> Know column data types</b>

# %%
df.dtypes
# Out:
# Date and Time                       object
# Battery Voltage                    float64
# CR10 Temperature                   float64
# Wind Direction 10 Minutes          float64
# Wind Speed 10 Minutes              float64
# Wind Gust 10 Minutes               float64
# Hourly Average Direction             int64
# Hourly Average Speed               float64
# Hourly Maximum Gust                float64
# Hourly Gust Time                    object
# Hourly Gust Direction              float64
# Last Minute Average Temperature    float64
# Total Hourly Rain                  float64
# Average RH over previous minute    float64
# Maximum Hourly Air Temperature     float64
# Minimum Hourly Air Temperature     float64
# Maximum Hourly Rainfall Rate       float64
# Time of Rainfall                    object
# dtype: object

# %% [markdown]
# ### 4. head() and tail() functions

# %%
df.head()
# Out:
#       Date and Time  Battery Voltage  CR10 Temperature  \
# 0  01/01/2004 00:00            14.13             13.77
# 1  01/01/2004 01:00            14.14             13.75
# 2  01/01/2004 02:00            14.14             13.71
# 3  01/01/2004 03:00            14.14             13.62
# 4  01/01/2004 04:00            14.14             13.55
#
#    Wind Direction 10 Minutes  Wind Speed 10 Minutes  Wind Gust 10 Minutes  \
# 0                      175.5                   7.59                 13.29
# 1                      191.5                  13.27                 25.48
# 2                      194.1                  11.88                 20.83
# 3                      188.6                  10.93                 18.62
# 4                      182.7                  11.51                 20.51
#
#    Hourly Average Direction  Hourly Average Speed  Hourly Maximum Gust  \
# 0                       160                  8.47                13.36
# ...

# %%
df.tail()
# Out:
#          Date and Time  Battery Voltage  CR10 Temperature  \
# 8779  31/12/2004 19:00            14.06             16.14
# 8780  31/12/2004 20:00            14.06             16.16
# 8781  31/12/2004 21:00            14.05             16.18
# 8782  31/12/2004 22:00            14.05             16.18
# 8783  31/12/2004 23:00            14.06             16.14
#
#       Wind Direction 10 Minutes  Wind Speed 10 Minutes  Wind Gust 10 Minutes  \
# 8779                      271.0                  5.751                 8.710
# 8780                      259.6                  5.897                 7.520
# 8781                      261.1                  5.310                 8.130
# 8782                      247.3                  6.135                 8.840
# 8783                      233.7                  3.784                 5.533
#
#       Hourly Average Direction  Hourly Average Speed  Hourly Maximum Gust  \
# 8779                       300                 7.360                17.17
# ...

# %%
df.head(2)
# Out:
#       Date and Time  Battery Voltage  CR10 Temperature  \
# 0  01/01/2004 00:00            14.13             13.77
# 1  01/01/2004 01:00            14.14             13.75
#
#    Wind Direction 10 Minutes  Wind Speed 10 Minutes  Wind Gust 10 Minutes  \
# 0                      175.5                   7.59                 13.29
# 1                      191.5                  13.27                 25.48
#
#    Hourly Average Direction  Hourly Average Speed  Hourly Maximum Gust  \
# 0                       160                  8.47                13.36
# 1                       180                  9.87                25.48
#
#   Hourly Gust Time  Hourly Gust Direction  Last Minute Average Temperature  \
# 0            23:28                  164.0                            5.437
# 1            00:58                  203.2                            5.627
#
#    Total Hourly Rain  Average RH over previous minute  \
# 0                0.0                              NaN
# ...

# %% [markdown]
# ### 4. to_numpy()

# %%
df.to_numpy()
# Out:
# array([['01/01/2004 00:00', 14.13, 13.77, ..., 4.581, 0.0, '23:01'],
#        ['01/01/2004 01:00', 14.14, 13.75, ..., 5.4510000000000005, 0.0,
#         '00:01'],
#        ['01/01/2004 02:00', 14.14, 13.71, ..., 3.8789999999999996, 1.2,
#         '01:20'],
#        ...,
#        ['31/12/2004 21:00', 14.05, 16.18, ..., 8.87, 0.0, '20:01'],
#        ['31/12/2004 22:00', 14.05, 16.18, ..., 8.29, 0.0, '21:01'],
#        ['31/12/2004 23:00', 14.06, 16.14, ..., 7.99, 0.0, '22:01']],
#       dtype=object)

# %% [markdown]
# ### 5. describe()

# %%
df.describe()
# Out:
#        Battery Voltage  CR10 Temperature  Wind Direction 10 Minutes  \
# count      8784.000000       8784.000000                8784.000000
# mean         13.967951         19.270093                 203.614921
# std           0.124551          4.178242                  94.006834
# min          13.670000         11.520000                   0.024000
# 25%          13.870000         15.770000                 125.175000
# 50%          13.980000         18.830000                 234.700000
# 75%          14.070000         22.510000                 269.100000
# max          14.200000         29.760000                 359.900000
#
#        Wind Speed 10 Minutes  Wind Gust 10 Minutes  Hourly Average Direction  \
# count             8784.00000           8784.000000               8784.000000
# mean                 8.24043             13.448078                205.297131
# std                  4.09377              6.720263                 94.200389
# ...

# %% [markdown]
# ### 6. sort_index() / sort_values()

# %%
df.sort_index(axis=1,ascending=True)
# Out:
#       Average RH over previous minute  Battery Voltage  CR10 Temperature  \
# 0                                 NaN            14.13             13.77
# 1                                 NaN            14.14             13.75
# 2                                 NaN            14.14             13.71
# 3                                 NaN            14.14             13.62
# 4                                 NaN            14.14             13.55
# ...                               ...              ...               ...
# 8779                              NaN            14.06             16.14
# 8780                              NaN            14.06             16.16
# 8781                              NaN            14.05             16.18
# 8782                              NaN            14.05             16.18
# 8783                              NaN            14.06             16.14
#
#          Date and Time  Hourly Average Direction  Hourly Average Speed  \
# ...

# %%
df.sort_values('Hourly Gust Direction',ascending=False)
# Out:
#          Date and Time  Battery Voltage  CR10 Temperature  \
# 7568  11/11/2004 08:00            14.02             17.49
# 8077  02/12/2004 13:00            14.09             15.40
# 415   18/01/2004 07:00            14.15             13.25
# 7557  10/11/2004 21:00            14.01             17.93
# 7547  10/11/2004 11:00            14.03             17.28
# ...                ...              ...               ...
# 2474  13/04/2004 02:00            13.97             18.92
# 1594  07/03/2004 10:00            14.07             15.66
# 1363  26/02/2004 19:00            14.16             12.87
# 7569  11/11/2004 09:00            14.03             17.40
# 330   14/01/2004 18:00            14.14             13.58
#
#       Wind Direction 10 Minutes  Wind Speed 10 Minutes  Wind Gust 10 Minutes  \
# 7568                    339.400                  8.620                14.960
# 8077                    359.900                  4.134                 6.655
# ...

# %% [markdown]
# ### 7. Selecting a single column

# %%
df['CR10 Temperature']
# Out:
# 0       13.77
# 1       13.75
# 2       13.71
# 3       13.62
# 4       13.55
#         ...
# 8779    16.14
# 8780    16.16
# 8781    16.18
# 8782    16.18
# 8783    16.14
# Name: CR10 Temperature, Length: 8784, dtype: float64

# %% [markdown]
# ### 8. Slicing rows

# %%
df_sample=df[0:3]
df_sample
# Out:
#       Date and Time  Battery Voltage  CR10 Temperature  \
# 0  01/01/2004 00:00            14.13             13.77
# 1  01/01/2004 01:00            14.14             13.75
# 2  01/01/2004 02:00            14.14             13.71
#
#    Wind Direction 10 Minutes  Wind Speed 10 Minutes  Wind Gust 10 Minutes  \
# 0                      175.5                   7.59                 13.29
# 1                      191.5                  13.27                 25.48
# 2                      194.1                  11.88                 20.83
#
#    Hourly Average Direction  Hourly Average Speed  Hourly Maximum Gust  \
# 0                       160                  8.47                13.36
# 1                       180                  9.87                25.48
# 2                       200                 14.55                26.99
#
#   Hourly Gust Time  Hourly Gust Direction  Last Minute Average Temperature  \
# 0            23:28                  164.0                            5.437
# ...

# %% [markdown]
# ### 9. Result on condition basis

# %%
df[df['CR10 Temperature']>14]
# Out:
#          Date and Time  Battery Voltage  CR10 Temperature  \
# 115   05/01/2004 19:00            14.12             14.04
# 116   05/01/2004 20:00            14.12             14.11
# 117   05/01/2004 21:00            14.12             14.15
# 118   05/01/2004 22:00            14.12             14.22
# 119   05/01/2004 23:00            14.12             14.26
# ...                ...              ...               ...
# 8779  31/12/2004 19:00            14.06             16.14
# 8780  31/12/2004 20:00            14.06             16.16
# 8781  31/12/2004 21:00            14.05             16.18
# 8782  31/12/2004 22:00            14.05             16.18
# 8783  31/12/2004 23:00            14.06             16.14
#
#       Wind Direction 10 Minutes  Wind Speed 10 Minutes  Wind Gust 10 Minutes  \
# 115                       245.2                  8.070                12.680
# 116                       236.7                  9.630                13.420
# ...

# %% [markdown]
# ### 10. copy()

# %%
df_copy=df.copy()
df_copy
# Out:
#          Date and Time  Battery Voltage  CR10 Temperature  \
# 0     01/01/2004 00:00            14.13             13.77
# 1     01/01/2004 01:00            14.14             13.75
# 2     01/01/2004 02:00            14.14             13.71
# 3     01/01/2004 03:00            14.14             13.62
# 4     01/01/2004 04:00            14.14             13.55
# ...                ...              ...               ...
# 8779  31/12/2004 19:00            14.06             16.14
# 8780  31/12/2004 20:00            14.06             16.16
# 8781  31/12/2004 21:00            14.05             16.18
# 8782  31/12/2004 22:00            14.05             16.18
# 8783  31/12/2004 23:00            14.06             16.14
#
#       Wind Direction 10 Minutes  Wind Speed 10 Minutes  Wind Gust 10 Minutes  \
# 0                         175.5                  7.590                13.290
# 1                         191.5                 13.270                25.480
# ...

# %% [markdown]
# ### 11. Adding a new column in the data frame

# %%
df_copy['Day']= ['Heavey Rain' if x >= 0.5 else 'Rainy/Not' for x in df['Total Hourly Rain'] ]
df_copy
# Out:
#          Date and Time  Battery Voltage  CR10 Temperature  \
# 0     01/01/2004 00:00            14.13             13.77
# 1     01/01/2004 01:00            14.14             13.75
# 2     01/01/2004 02:00            14.14             13.71
# 3     01/01/2004 03:00            14.14             13.62
# 4     01/01/2004 04:00            14.14             13.55
# ...                ...              ...               ...
# 8779  31/12/2004 19:00            14.06             16.14
# 8780  31/12/2004 20:00            14.06             16.16
# 8781  31/12/2004 21:00            14.05             16.18
# 8782  31/12/2004 22:00            14.05             16.18
# 8783  31/12/2004 23:00            14.06             16.14
#
#       Wind Direction 10 Minutes  Wind Speed 10 Minutes  Wind Gust 10 Minutes  \
# 0                         175.5                  7.590                13.290
# 1                         191.5                 13.270                25.480
# ...

# %%
df_copy['Day']
# Out:
# 0         Rainy/Not
# 1         Rainy/Not
# 2       Heavey Rain
# 3       Heavey Rain
# 4         Rainy/Not
#            ...
# 8779      Rainy/Not
# 8780      Rainy/Not
# 8781      Rainy/Not
# 8782      Rainy/Not
# 8783      Rainy/Not
# Name: Day, Length: 8784, dtype: object

# %% [markdown]
# ### 12. Dropping Rows

# %%
df_copy['Average RH over previous minute']
# Out:
# 0      NaN
# 1      NaN
# 2      NaN
# 3      NaN
# 4      NaN
#         ..
# 8779   NaN
# 8780   NaN
# 8781   NaN
# 8782   NaN
# 8783   NaN
# Name: Average RH over previous minute, Length: 8784, dtype: float64

# %%
df_copy.dropna(how='any',inplace=True)
df_copy
# Out:
# Empty DataFrame
# Columns: [Date and Time, Battery Voltage, CR10 Temperature, Wind Direction 10 Minutes, Wind Speed 10 Minutes, Wind Gust 10 Minutes, Hourly Average Direction, Hourly Average Speed, Hourly Maximum Gust, Hourly Gust Time, Hourly Gust Direction, Last Minute Average Temperature, Total Hourly Rain, Average RH over previous minute, Maximum Hourly Air Temperature, Minimum Hourly Air Temperature, Maximum Hourly Rainfall Rate, Time of Rainfall, Day]
# Index: []

# %%
df_copy['Average RH over previous minute']
# Out:
# Series([], Name: Average RH over previous minute, dtype: float64)

# %% [markdown]
# ### 13. Filling NaN values

# %%
df.fillna(value=5,inplace=True)

# %%
df['Average RH over previous minute']
# Out:
# 0       5.0
# 1       5.0
# 2       5.0
# 3       5.0
# 4       5.0
#        ...
# 8779    5.0
# 8780    5.0
# 8781    5.0
# 8782    5.0
# 8783    5.0
# Name: Average RH over previous minute, Length: 8784, dtype: float64

# %% [markdown]
# ##### Refrences:
# 1. https://towardsdatascience.com/pandas-guide-with-python-example-ii-basic-pandas-operations-4cf9704fd062
# 2. https://www.learndatasci.com/tutorials/python-pandas-tutorial-complete-introduction-for-beginners/
